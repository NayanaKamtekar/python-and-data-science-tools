# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('responses.csv', delimiter = ",") # read in the data and print it
df # Note that the first line of the csv-file is interpreted as variable names (which fits in this case!).
# Out:
#     Unnamed: 0   type      exp      cor  diff  hour   sec  \
# 0            1  Latin  Yes, No  Yes, No   5.0    17  68.0
# 1            2  Greek      Yes       No  10.0    17   4.0
# 2            3  Latin       No      Yes   5.0    20  54.0
# 3            4  Greek      Yes      Yes   3.0    20  11.0
# 4            5  Latin      Yes      Yes   1.0    20   5.0
# 5            6  Greek      Yes      Yes   3.0    20   NaN
# 6            7  Latin      Yes       No  10.0    20   NaN
# 7            8  Greek       No       No   7.0    20   9.0
# 8            9  Latin      Yes      Yes  10.0    20   NaN
# 9           10  Latin      Yes      Yes   6.0    20   NaN
# 10          11  Latin      Yes      Yes   1.0    11   NaN
# 11          12  Latin      Yes      Yes   1.0    11   NaN
# 12          13  Greek      Yes      Yes   1.0    11   NaN
# 13          14  Greek      Yes      Yes   3.0    12   NaN
# 14          15    NaN      NaN      NaN   NaN    21   NaN
# ...

# %%
df.loc[df['type'].isin(['Latin','Greek'])]
# Out:
#     Unnamed: 0   type      exp      cor  diff  hour   sec  \
# 0            1  Latin  Yes, No  Yes, No   5.0    17  68.0
# 1            2  Greek      Yes       No  10.0    17   4.0
# 2            3  Latin       No      Yes   5.0    20  54.0
# 3            4  Greek      Yes      Yes   3.0    20  11.0
# 4            5  Latin      Yes      Yes   1.0    20   5.0
# 5            6  Greek      Yes      Yes   3.0    20   NaN
# 6            7  Latin      Yes       No  10.0    20   NaN
# 7            8  Greek       No       No   7.0    20   9.0
# 8            9  Latin      Yes      Yes  10.0    20   NaN
# 9           10  Latin      Yes      Yes   6.0    20   NaN
# 10          11  Latin      Yes      Yes   1.0    11   NaN
# 11          12  Latin      Yes      Yes   1.0    11   NaN
# 12          13  Greek      Yes      Yes   1.0    11   NaN
# 13          14  Greek      Yes      Yes   3.0    12   NaN
# 15          16  Greek      Yes      Yes   7.0    21   1.0
# ...

# %%
df['num_min']= pd.to_numeric(df['min'], errors='coerce')
df
# Out:
#     Unnamed: 0   type      exp      cor  diff  hour   sec  \
# 0            1  Latin  Yes, No  Yes, No   5.0    17  68.0
# 1            2  Greek      Yes       No  10.0    17   4.0
# 2            3  Latin       No      Yes   5.0    20  54.0
# 3            4  Greek      Yes      Yes   3.0    20  11.0
# 4            5  Latin      Yes      Yes   1.0    20   5.0
# 5            6  Greek      Yes      Yes   3.0    20   NaN
# 6            7  Latin      Yes       No  10.0    20   NaN
# 7            8  Greek       No       No   7.0    20   9.0
# 8            9  Latin      Yes      Yes  10.0    20   NaN
# 9           10  Latin      Yes      Yes   6.0    20   NaN
# 10          11  Latin      Yes      Yes   1.0    11   NaN
# 11          12  Latin      Yes      Yes   1.0    11   NaN
# 12          13  Greek      Yes      Yes   1.0    11   NaN
# 13          14  Greek      Yes      Yes   3.0    12   NaN
# 14          15    NaN      NaN      NaN   NaN    21   NaN
# ...

# %%
df.loc[(df['sec'] <= 60) | (df['sec'].isna())]
# Out:
#     Unnamed: 0   type  exp  cor  diff  hour   sec  \
# 1            2  Greek  Yes   No  10.0    17   4.0
# 2            3  Latin   No  Yes   5.0    20  54.0
# 3            4  Greek  Yes  Yes   3.0    20  11.0
# 4            5  Latin  Yes  Yes   1.0    20   5.0
# 5            6  Greek  Yes  Yes   3.0    20   NaN
# 6            7  Latin  Yes   No  10.0    20   NaN
# 7            8  Greek   No   No   7.0    20   9.0
# 8            9  Latin  Yes  Yes  10.0    20   NaN
# 9           10  Latin  Yes  Yes   6.0    20   NaN
# 10          11  Latin  Yes  Yes   1.0    11   NaN
# 11          12  Latin  Yes  Yes   1.0    11   NaN
# 12          13  Greek  Yes  Yes   1.0    11   NaN
# 13          14  Greek  Yes  Yes   3.0    12   NaN
# 14          15    NaN  NaN  NaN   NaN    21   NaN
# 15          16  Greek  Yes  Yes   7.0    21   1.0
# 16          17  Greek   No  Yes   3.0     0   NaN
#
#                                                   min  \
# ...

# %%
df1 = pd.read_csv('SMSSpamCollection.txt', delimiter = "\t", names=['s','t'])

# %%
df1.head(50)
# Out:
#        s                                                  t
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...
# 6    ham  Even my brother is not like to speak with me. ...
# 7    ham  As per your request 'Melle Melle (Oru Minnamin...
# 8   spam  WINNER!! As a valued network customer you have...
# 9   spam  Had your mobile 11 months or more? U R entitle...
# 10   ham  I'm gonna be home soon and i don't want to tal...
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...
# 12  spam  URGENT! You have won a 1 week FREE membership ...
# 13   ham  I've been searching for the right words to tha...
# 14   ham                I HAVE A DATE ON SUNDAY WITH WILL!!
# ...

# %%
df1['num']= df1.t.str.count('\d')

# %%
import re
df1['l'] = df1['t'].str.len()

# %%
df1.head(50)
# Out:
#        s                                                  t  num    l
# 0    ham  Go until jurong point, crazy.. Available only ...    0  111
# 1    ham                      Ok lar... Joking wif u oni...    0   29
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...   25  155
# 3    ham  U dun say so early hor... U c already then say...    0   49
# 4    ham  Nah I don't think he goes to usf, he lives aro...    0   61
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...    4  147
# 6    ham  Even my brother is not like to speak with me. ...    0   77
# 7    ham  As per your request 'Melle Melle (Oru Minnamin...    1  160
# 8   spam  WINNER!! As a valued network customer you have...   19  157
# 9   spam  Had your mobile 11 months or more? U R entitle...   13  154
# 10   ham  I'm gonna be home soon and i don't want to tal...    0  109
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...   22  136
# ...
